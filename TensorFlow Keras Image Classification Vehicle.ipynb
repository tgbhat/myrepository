# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications import imagenet_utils

# %%
filename = 'C:/Users/Tathagat/Documents/Images/IMG_6082.jpg'

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))

# %%
plt.imshow(img)

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img, axis=0)
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
predictions = mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n04389033', 'tank', 0.99973685), ('n02950826', 'cannon', 0.00018150156), ('n03478589', 'half_track', 3.1140815e-05), ('n03967562', 'plow', 1.7949113e-05), ('n03496892', 'harvester', 1.3171322e-05)]]

# %%
# The five predictions made for the image is 'tank' with 99.97% probability, 'cannon' with 0.018% probability, then 
# 'half_track', then 'plow', then 'harvester' with much smaller probabilities

# %%
# The first prediction is the most accurate because the image is actually a photo I took of a
# M4 Sherman tank at an US Army museum
